# %%
# %pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.19.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/rahesh/opt/anaconda3/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.4)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.25.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi>=2021.10.8 (from selenium)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing_extensions>=4.9.0 in /Users/rahesh/opt/anaconda3/lib/python3.8/site-packages (from selenium) (4.11.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sortedcontainers in /Users/rahesh/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: idna in /Users/rahesh/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: exceptiongroup in /Users/rahesh/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.2.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/rahesh/opt/anaconda3/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/rahesh/opt/anaconda3/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.19.0-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 31.6 MB/s eta 0:00:00a 0:00:01
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Downloading trio-0.25.0-py3-none-any.whl (467 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 31.6 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: wsproto, sniffio, certifi, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.3.0
#     Uninstalling attrs-20.3.0:
#       Successfully uninstalled attrs-20.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqt5<5.13, which is not installed.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# tensorflow 2.13.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.11.0 which is incompatible.
# Successfully installed attrs-23.2.0 certifi-2024.2.2 outcome-1.3.0.post0 selenium-4.19.0 sniffio-1.3.1 trio-0.25.0 trio-websocket-0.11.1 wsproto-1.2.0
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: /Users/rahesh/opt/anaconda3/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')

# %%
user_input_job_title = input('Enter Job Titles (with comma separated):').split()
print(user_input_job_title)
# Out:
# Enter Job Titles (with comma separated):Data Analyst
# ['Data', 'Analyst']

# %%
user_input_job_title
# Out:
# ['Data', 'Analyst']

# %%
b = []
for i in user_input_job_title:
    x = i.split()
    y = '%20'.join(x)
    b.append(y)

job_title = '%2C%20'.join(b)
print(job_title)
# Out:
# Data%2C%20Analyst

# %%
link = f"https://in.linkedin.com/jobs/search?keywords={job_title}&location=India&locationId=&geoId=102713980&f_TPR=r604800&position=1&pageNum=0"
print(link)
# Out:
# https://in.linkedin.com/jobs/search?keywords=Data%2C%20Analyst&location=India&locationId=&geoId=102713980&f_TPR=r604800&position=1&pageNum=0

# %%
driver = webdriver.Chrome()
driver.maximize_window()

driver.get(link)
driver.implicitly_wait(10)

# %%
for i in range(0,2):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

    try:
        x = driver.find_element(by=By.CSS_SELECTOR, value="button[aria-label='See more jobs']").click()
        time.sleep(3)
    except:
        pass

# %%
company_name = []

try:
    company = driver.find_elements(by=By.CSS_SELECTOR, value='h4[class="base-search-card__subtitle"]')
    for i in company:
        company_name.append(i.text)

except:
    pass

print(company_name)
# Out:
# ['Crum & Forster', 'Amazon', 'Helmerich & Payne', 'Volvo Group', 'Rebel Foods', 'Masai', 'Greystar (International)', 'Decathlon Sports India', 'Kraft Heinz', 'Kraft Heinz', 'Zensar Technologies', 'Amazon', 'HP', 'FedEx ACC', 'Experian', 'Target', 'Delta Air Lines', 'Midtown Software', 'Virtusa', 'Pulsus Group LTD', 'Juno', 'Signant Health', 'HP', 'Tata Consultancy Services', 'Postman', 'Freshworks', 'Consulting Company', 'CoinSwitch', 'HP', 'TresVista', 'Epsilon India', 'Quiktrak, LLC', 'L3Harris Technologies', 'Target', 'dentsu', 'TekJobs', 'Responsive', 'Peoplefy', 'RiskInsight Consulting Pvt Ltd.', 'Pinnacle Group, Inc.', 'Enphase Energy', 'Grazitti Interactive', 'Luxoft', 'Razorpay', 'DecisionTree Analytics & Services', 'Egis in India', 'Gameskraft', 'Brillio', 'DataZymes', 'Amber', 'Tatvic ®', 'ConTecHub', 'Michelin', 'NOV', 'Viacom18 Media Private Limited', 'Idyllic Services Pvt. Ltd.', 'NTT DATA North America', 'SmartQ']

# %%
job_title = []

try:
    title = driver.find_elements(by=By.CSS_SELECTOR, value='h3[class="base-search-card__title"]')
    for i in title:
        job_title.append(i.text)

except:
    pass

print(job_title)
# Out:
# ['Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst-I', 'Data Analytics (0-1 Year Experience)', 'Data Analyst', 'Senior Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst, Global Trade', 'Marketing Data Analyst', 'Data Analyst [T500-11299]', 'Data Analyst', 'Data Analyst', 'Senior Data Analyst [T500-11067]', 'Data Analyst', 'Data Analyst', 'Data Visualisation Analyst', 'Data Analyst', 'Data Analyst II', 'Data Analyst', 'Data Analyst', 'Data Analyst II', 'Principal Analyst - Marketing Analytics', 'Data Analyst', 'Lead Data Analyst', 'Data Analyst/ Engineer', 'Analyst - Data Intelligence Group - Data Engineering - Bengaluru/Pune', 'Senior Data Analyst', 'Data Analyst', 'Data Analyst', 'Sr Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst (US Shift)', 'Data Analytics', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Business/Data Analyst Analytics', 'Senior Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst / Business Analyst', 'Senior Data Analyst', 'Lead Data Analyst', 'Senior Analyst -Analytics (Power BI)', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst_2', 'Data Analyst', 'Data Analyst', 'Data Analyst-PySpark', 'Data Analyst, Tableau', 'Data Analyst']

# %%
company_location = []

try:
    location = driver.find_elements(by=By.CSS_SELECTOR, value='span[class="job-search-card__location"]')
    for i in location:
        company_location.append(i.text)

except:
    pass

print(company_location)
# Out:
# ['Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'North Goa, Goa, India', 'Hoskote, Karnataka, India', 'Mumbai, Maharashtra, India', 'Bengaluru, Karnataka, India', 'Mohali district, India', 'Bengaluru North, Karnataka, India', 'Ahmedabad, Gujarat, India', 'Ahmedabad, Gujarat, India', 'Hyderabad, Telangana, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Hyderabad, Telangana, India', 'Mumbai Metropolitan Region', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Chandigarh, India', 'Andhra Pradesh, India', 'Hyderabad, Telangana, India', 'Bengaluru, Karnataka, India', 'Greater Hyderabad Area', 'Chennai, Tamil Nadu, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Hyderabad, Telangana, India', 'Delhi, India', 'Bangalore Urban, Karnataka, India', 'Mumbai, Maharashtra, India', 'India', 'Bengaluru, Karnataka, India', 'Hyderabad, Telangana, India', 'Bengaluru, Karnataka, India', 'Chennai, Tamil Nadu, India', 'Bengaluru East, Karnataka, India', 'Panchkula, Haryana, India', 'Pune, Maharashtra, India', 'Bengaluru, Karnataka, India', 'Gurgaon, Haryana, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Greater Bengaluru Area', 'Bengaluru, Karnataka, India', 'Pune, Maharashtra, India', 'Ahmedabad, Gujarat, India', 'Jaipur, Rajasthan, India', 'Pune, Maharashtra, India', 'Navi Mumbai, Maharashtra, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru East, Karnataka, India', 'Bengaluru, Karnataka, India']

# %%
job_url = []

try:
    url = driver.find_elements(by=By.XPATH, value='//a[contains(@href, "/jobs/")]')
    for i in url:
        job_url.append(i.get_attribute('href'))

except:
    pass

print(job_url)
# Out:
# ['https://in.linkedin.com/jobs/view/data-analyst-at-crum-forster-3868419975?position=1&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=0Hfwj1cKYPJcZP9hPoiekA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-amazon-3901710478?position=2&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=rVdJ5%2BnY8Hh7Lgu6R2nXVA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-helmerich-payne-3897710307?position=3&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=YrHQImi5h19KhmkIV%2FzEMQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-volvo-group-3900523046?position=4&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=RufR9pgcizL6lUytMS6vdA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-i-at-rebel-foods-3900892007?position=5&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=PjIa8imsz6KKrslotmyk1A%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analytics-0-1-year-experience-at-masai-3905607817?position=6&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=vZn3UtqZTotgZpLNZslgKQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-greystar-international-3890937042?position=7&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=gVmZJSuJpmAtDXnQfRCBqg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/senior-data-analyst-at-decathlon-sports-india-3903721378?position=8&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=OiHcxF52xwY7DfX9tSIgeg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-kraft-heinz-3901329745?position=9&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=86wJrsGEcfZIV73L8WiWVQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-kraft-heinz-3901325900?position=10&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=4epKCQ11r1MWxokl5hs0uQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-zensar-technologies-3897077179?position=11&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=vd%2BriodLlevEBVVmMLKCsg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-global-trade-at-amazon-3899387064?position=12&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=rWxg0z%2FCrBt9f%2F%2BjcbHPRQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/marketing-data-analyst-at-hp-3900775726?position=13&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=oe3%2Bzy5JuiycmPIcokOjzA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-t500-11299-at-fedex-acc-3893951407?position=14&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=lcPMiYQaWrxo%2BqdWpKAKCA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-experian-3905685186?position=15&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=u%2F%2BG3G3yYa%2FNT%2B85wGUfpw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-target-3902343770?position=16&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=8n0bCmE%2Fdmn%2BDTPSZpZi1g%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/senior-data-analyst-t500-11067-at-delta-air-lines-3870662201?position=17&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=uYVVEgWIbsceOXhfYrS6Pg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/data-analyst-at-midtown-software-3885127542?position=18&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=%2Bw7q6AA7WSAAHROnMiehPw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view ...

# %%
df = pd.DataFrame(company_name, columns=['Company Name'])
df['Job Title'] = pd.DataFrame(job_title)
df['Location'] = pd.DataFrame(company_location)
df['Website URL'] = pd.DataFrame(job_url)
df
# Out:
#                          Company Name  \
# 0                      Crum & Forster
# 1                              Amazon
# 2                   Helmerich & Payne
# 3                         Volvo Group
# 4                         Rebel Foods
# 5                               Masai
# 6            Greystar (International)
# 7              Decathlon Sports India
# 8                         Kraft Heinz
# 9                         Kraft Heinz
# 10                Zensar Technologies
# 11                             Amazon
# 12                                 HP
# 13                          FedEx ACC
# 14                           Experian
# 15                             Target
# 16                    Delta Air Lines
# 17                   Midtown Software
# 18                            Virtusa
# 19                   Pulsus Group LTD
# 20                               Juno
# 21                     Signant Health
# 22                                 HP
# 23          Tata Consultancy Services
# 24                            Postman
# 25                         Freshworks
# 26                 Consulting Company
# 27                         CoinSwitch
# 28                                 HP
# 29                          TresVista
# 30                      Epsilon India
# 31                      Quiktrak, LLC
# 32              L3Harris Technologies
# 33                             Target
# 34                             dentsu
# 35                            TekJobs
# 36                         Responsive
# 37                           Peoplefy
# 38    RiskInsight Consulting Pvt Ltd.
# 39               Pinnacle Group, Inc.
# 40                     Enphase Energy
# 41               Grazitti Interactive
# 42                             Luxoft
# 43                           Razorpay
# 44  DecisionTree Analytics & Services
# 45                      Egis in India
# 46                         Gameskraft
# 47                            Brillio
# 48                          DataZymes
# 49                              Amber
# 50                           Tatvic ®
# 51                          ConTecHub
# 52                           Michelin
# 53                                NOV
# 54     Viacom18 Media Private Limited
# 55         Idyllic Services Pvt. Ltd.
# 56             NTT DATA North America
# 57                             SmartQ
#
#                                             Job Title  \
# 0                                        Data Analyst
# 1                                        Data Analyst
# 2                                        Data Analyst
# 3                                        Data Analyst
# 4                                      Data Analyst-I
# 5                Data Analytics (0-1 Year Experience)
# 6                                        Data Analyst
# 7                                 Senior Data Analyst
# 8                                        Data Analyst
# 9                                        Data Analyst
# 10                                       Data Analyst
# 11                         Data Analyst, Global Trade
# 12                             Marketing Data Analyst
# 13                          Data Analyst [T500-11299]
# 14                                       Data Analyst
# 15                                       Data Analyst
# 16                   Senior Data Analyst [T500-11067]
# 17                                       Data Analyst
# 18                                       Data Analyst
# 19                         Data Visualisation Analyst
# 20                                       Data Analyst
# 21                                    Data Analyst II
# 22                                       Data Analyst
# 23                                       Data Analyst
# 24                                    Data Analyst II
# 25            Principal Analyst - Marketing Analytics
# 26                                       Data Analyst
# 27                                  Lead Data Analyst
# 28                             Data Analyst/ Engineer
# 29  Analyst - Data Intelligence Group - Data Engin...
# 30                                Senior Data Analyst
# 31                                       Data Analyst
# 32                                       Data Analyst
# 33                                    Sr Data Analyst
# 34                                       Data Analyst
# 35                                       Data Analyst
# 36                            Data Analyst (US Shift)
# 37                                     Data Analytics
# 38                                       Data Analyst
# 39                                       Data Analyst
# 40                                       Data Analyst
# 41                    Business/Data Analyst Analytics
# 42                                Senior Data Analyst
# 43                                       Data Analyst
# 44                                       Data Analyst
# 45                    Data Analyst / Business Analyst
# 46                                Senior Data Analyst
# 47                                  Lead Data Analyst
# 48               Senior Analyst -Analytics (Power BI)
# 49                                       Data Analyst
# 50                                       Data Analyst
# 51                                       Data Analyst
# 52                                     Data Analyst_2
# 53                                       Data Analyst
# 54                                       Data Analyst
# 55                               Data Analyst-PySpark
# 56                              Data Analyst, Tableau
# 57                                       Data Analyst
#
#                              Location  \
# 0         Bengaluru, Karnataka, India
# 1         Bengaluru, Karnataka, India
# 2               North Goa, Goa, India
# 3           Hoskote, Karnataka, India
# 4          Mumbai, Maharashtra, India
# 5         Bengaluru, Karnataka, India
# 6              Mohali district, India
# 7   Bengaluru North, Karnataka, India
# 8           Ahmedabad, Gujarat, India
# 9           Ahmedabad, Gujarat, India
# 10        Hyderabad, Telangana, India
# 11        Bengaluru, Karnataka, India
# 12        Bengaluru, Karnataka, India
# 13        Hyderabad, Telangana, India
# 14         Mumbai Metropolitan Region
# 15        Bengaluru, Karnataka, India
# 16        Bengaluru, Karnataka, India
# 17                  Chandigarh, India
# 18              Andhra Pradesh, India
# 19        Hyderabad, Telangana, India
# 20        Bengaluru, Karnataka, India
# 21             Greater Hyderabad Area
# 22         Chennai, Tamil Nadu, India
# 23        Bengaluru, Karnataka, India
# 24        Bengaluru, Karnataka, India
# 25        Bengaluru, Karnataka, India
# 26                              India
# 27        Bengaluru, Karnataka, India
# 28        Bengaluru, Karnataka, India
# 29        Bengaluru, Karnataka, India
# 30        Bengaluru, Karnataka, India
# 31        Hyderabad, Telangana, India
# 32                       Delhi, India
# 33  Bangalore Urban, Karnataka, India
# 34         Mumbai, Maharashtra, India
# 35                              India
# 36        Bengaluru, Karnataka, India
# 37        Hyderabad, Telangana, India
# 38        Bengaluru, Karnataka, India
# 39         Chennai, Tamil Nadu, India
# 40   Bengaluru East, Karnataka, India
# 41          Panchkula, Haryana, India
# 42           Pune, Maharashtra, India
# 43        Bengaluru, Karnataka, India
# 44            Gurgaon, Haryana, India
# 45        Bengaluru, Karnataka, India
# 46        Bengaluru, Karnataka, India
# 47             Greater Bengaluru Area
# 48        Bengaluru, Karnataka, India
# 49           Pune, Maharashtra, India
# 50          Ahmedabad, Gujarat, India
# 51           Jaipur, Rajasthan, India
# 52           Pune, Maharashtra, India
# 53    Navi Mumbai, Maharashtra, India
# 54        Bengaluru, Karnataka, India
# 55        Bengaluru, Karnataka, India
# 56   Bengaluru East, Karnataka, India
# 57        Bengaluru, Karnataka, India
#
#                                           Website URL
# 0   https://in.linkedin.com/jobs/view/data-analyst...
# 1   https://in.linkedin.com/jobs/view/data-analyst...
# 2   https://in.linkedin.com/jobs/view/data-analyst...
# 3   https://in.linkedin.com/jobs/view/data-analyst...
# 4   https://in.linkedin.com/jobs/view/data-analyst...
# 5   https://in.linkedin.com/jobs/view/data-analyti...
# 6   https://in.linkedin.com/jobs/view/data-analyst...
# 7   https://in.linkedin.com/jobs/view/senior-data-...
# 8   https://in.linkedin.com/jobs/view/data-analyst...
# 9   https://in.linkedin.com/jobs/view/data-analyst...
# 10  https://in.linkedin.com/jobs/view/data-analyst...
# 11  https://in.linkedin.com/jobs/view/data-analyst...
# 12  https://in.linkedin.com/jobs/view/marketing-da...
# 13  https://in.linkedin.com/jobs/view/data-analyst...
# 14  https://in.linkedin.com/jobs/view/data-analyst...
# 15  https://in.linkedin.com/jobs/view/data-analyst...
# 16  https://in.linkedin.com/jobs/view/senior-data-...
# 17  https://in.linkedin.com/jobs/view/data-analyst...
# 18  https://in.linkedin.com/jobs/view/data-analyst...
# 19  https://in.linkedin.com/jobs/view/data-visuali...
# 20  https://in.linkedin.com/jobs/view/data-analyst...
# 21  https://in.linkedin.com/jobs/view/data-analyst...
# 22  https://in.linkedin.com/jobs/view/data-analyst...
# 23  https://in.linkedin.com/jobs/view/data-analyst...
# 24  https://in.linkedin.com/jobs/view/data-analyst...
# 25  https://in.linkedin.com/jobs/view/principal-an...
# 26  https://in.linkedin.com/jobs/view/data-analyst...
# 27  https://in.linkedin.com/jobs/view/lead-data-an...
# 28  https://in.linkedin.com/jobs/view/data-analyst...
# 29  https://in.linkedin.com/jobs/view/analyst-data...
# 30  https://in.linkedin.com/jobs/view/senior-data-...
# 31  https://in.linkedin.com/jobs/view/data-analyst...
# 32  https://in.linkedin.com/jobs/view/data-analyst...
# 33  https://in.linkedin.com/jobs/view/sr-data-anal...
# 34  https://in.linkedin.com/jobs/view/data-analyst...
# 35  https://in.linkedin.com/jobs/view/data-analyst...
# 36  https://in.linkedin.com/jobs/view/data-analyst...
# 37  https://in.linkedin.com/jobs/view/data-analyti...
# 38  https://in.linkedin.com/jobs/view/data-analyst...
# 39  https://in.linkedin.com/jobs/view/data-analyst...
# 40  https://in.linkedin.com/jobs/view/data-analyst...
# 41  https://in.linkedin.com/jobs/view/business-dat...
# 42  https://in.linkedin.com/jobs/view/senior-data-...
# 43  https://in.linkedin.com/jobs/view/data-analyst...
# 44  https://in.linkedin.com/jobs/view/data-analyst...
# 45  https://in.linkedin.com/jobs/view/data-analyst...
# 46  https://in.linkedin.com/jobs/view/senior-data-...
# 47  https://in.linkedin.com/jobs/view/lead-data-an...
# 48  https://in.linkedin.com/jobs/view/senior-analy...
# 49  https://in.linkedin.com/jobs/view/data-analyst...
# 50  https://in.linkedin.com/jobs/view/data-analyst...
# 51  https://in.linkedin.com/jobs/view/data-analyst...
# 52  https://in.linkedin.com/jobs/view/data-analyst...
# 53  https://in.linkedin.com/jobs/view/data-analyst...
# 54  https://in.linkedin.com/jobs/view/data-analyst...
# 55  https://in.linkedin.com/jobs/view/data-analyst...
# 56  https://in.linkedin.com/jobs/view/data-analyst...
# 57  https://in.linkedin.com/jobs/view/data-analyst...

# %%
df.to_csv('Data_Analyst.csv')

# %%
def job_title_filter(x, user_input_job_title):
    
    s = [i.lower() for i in user_input_job_title]
    suggestion = []
    for i in s:
        suggestion.extend(i.split())

    s = x.split()
    a = [i.lower() for i in s]
    
    intersection = list(set(suggestion).intersection(set(a)))
    return x if len(intersection)>1 else np.nan

# %%
df['Job Title'] = df['Job Title'].apply(lambda x: job_title_filter(x, user_input_job_title))
df=df.dropna()
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                  Company Name  \
# 0                            Technofactorx AI
# 1                         Zithas Technologies
# 2                                   Geektrust
# 3                           Bluebix Solutions
# 4                                      PloPdo
# 5                                    TechLadd
# 6               Whacked Out ® Media Pte. Ltd.
# 7                   Fusion Plus Solutions Inc
# 8                                       Wipro
# 9                                   futuremug
# 10                      Razormet Technologies
# 11                      Razormet Technologies
# 12                                    Genpact
# 13                      Razormet Technologies
# 14                    Braincuber Technologies
# 15                              HR Aspiration
# 16                     ExpertXai Technologies
# 17                                     PloPdo
# 18                           Matrix Marketers
# 19  Fynd (Shopsense Retail Technologies Ltd.)
# 20                  Fusion Plus Solutions Inc
# 21                        KamalDhari Infotech
# 22                                  Birlasoft
# 23                  Rapid Consulting Services
# 24                                    Sacumen
# 25                                   Ericsson
# 26                                   Ericsson
# 27                              Creospan Inc.
# 28                        HTC Global Services
# 29                                LTIMindtree
# 30                    InfraCloud Technologies
# 31                                    Virtusa
# 32                                    Siemens
# 33                                   Element8
# 34                              Capleo Global
# 35                                 Innovatily
# 36                        HTC Global Services
# 37                       Tamcherry - Zaportiv
# 38                                   hackajob
# 39                    ms.tech project service
# 40      HighPoints Technologies India (P) Ltd
# 41                         Universal Software
# 42                         marcus evans Group
# 43                                       Citi
#
#                                             Job Title  \
# 0                  Python Developer (Fresh Graduate)-
# 1                             Junior Python Developer
# 2                            Python Backend Developer
# 3                                    Python Developer
# 4                             Junior Python Developer
# 5                                    Python Developer
# 6                                    Python Developer
# 7                           Python Developer - Vihaan
# 8                                    Python Developer
# 9                                 Python Developer Jr
# 10                    Python Developer Trainee/Intern
# 11                    Python Developer Trainee/Intern
# 12                                   Python Developer
# 13                    Python Developer Trainee/Intern
# 14                                   Python Developer
# 15                                   Python Developer
# 16                   Python Developer (2023-24 Batch)
# 17                                   Python Developer
# 18                    Python Developer - Django/Flask
# 19       Backend Python Developer | SDE - 1 / SDE - 2
# 20                                   Python developer
# 21                                   Python Developer
# 22                                   Python Developer
# 23                                   Python Developer
# 24                                   Python Developer
# 25                                   Python Developer
# 26                                   Python Developer
# 27                                   Python Developer
# 28                                   Python Developer
# 29            Python + R Developer & Machine Learning
# 30                                   Python Developer
# 31                              Python Java Developer
# 32                                   Python Developer
# 33                            Python Django Developer
# 34                                   Python Developer
# 35  Innovatily - Python Developer - Artificial Int...
# 36                                   Python Developer
# 37                        Python Automation Developer
# 38                                   Python Developer
# 39                                   Python Developer
# 40                                   Python Developer
# 41                                   Python Developer
# 42                                   Python Developer
# 43                             Python Developer - C10
#
#                              Location  \
# 0                               India
# 1            Vadodara, Gujarat, India
# 2         Bengaluru, Karnataka, India
# 3         Hyderabad, Telangana, India
# 4         Noida, Uttar Pradesh, India
# 5            Pune, Maharashtra, India
# 6         Hyderabad, Telangana, India
# 7         Hyderabad, Telangana, India
# 8         Hyderabad, Telangana, India
# 9                Kochi, Kerala, India
# 10            Hubli, Karnataka, India
# 11  Thiruvananthapuram, Kerala, India
# 12        Bengaluru, Karnataka, India
# 13             Guwahati, Assam, India
# 14              Surat, Gujarat, India
# 15        Bengaluru, Karnataka, India
# 16                              India
# 17        Bengaluru, Karnataka, India
# 18      Chandigarh, Chandigarh, India
# 19         Mumbai, Maharashtra, India
# 20        Hyderabad, Telangana, India
# 21              Surat, Gujarat, India
# 22        Noida, Uttar Pradesh, India
# 23        Hyderabad, Telangana, India
# 24        Mangaluru, Karnataka, India
# 25        Bengaluru, Karnataka, India
# 26        Bengaluru, Karnataka, India
# 27           Pune, Maharashtra, India
# 28         Chennai, Tamil Nadu, India
# 29                 Maharashtra, India
# 30                              India
# 31  Bangalore Urban, Karnataka, India
# 32         Chennai, Tamil Nadu, India
# 33           Kozhikode, Kerala, India
# 34        Hyderabad, Telangana, India
# 35        Bengaluru, Karnataka, India
# 36         Chennai, Tamil Nadu, India
# 37               Greater Kolkata Area
# 38         Chennai, Tamil Nadu, India
# 39                              India
# 40           Gurugram, Haryana, India
# 41          Ahmedabad, Gujarat, India
# 42         Mumbai, Maharashtra, India
# 43         Mumbai, Maharashtra, India
#
#                                           Website URL
# 0   https://in.linkedin.com/jobs/view/python-devel...
# 1   https://in.linkedin.com/jobs/view/junior-pytho...
# 2   https://in.linkedin.com/jobs/view/python-backe...
# 3   https://in.linkedin.com/jobs/view/python-devel...
# 4   https://in.linkedin.com/jobs/view/junior-pytho...
# 5   https://in.linkedin.com/jobs/view/python-devel...
# 6   https://in.linkedin.com/jobs/view/python-devel...
# 7   https://in.linkedin.com/jobs/view/python-devel...
# 8   https://in.linkedin.com/jobs/view/python-devel...
# 9   https://in.linkedin.com/jobs/view/python-devel...
# 10  https://in.linkedin.com/jobs/view/python-devel...
# 11  https://in.linkedin.com/jobs/view/python-devel...
# 12  https://in.linkedin.com/jobs/view/python-devel...
# 13  https://in.linkedin.com/jobs/view/python-devel...
# 14  https://in.linkedin.com/jobs/view/python-devel...
# 15  https://in.linkedin.com/jobs/view/python-devel...
# 16  https://in.linkedin.com/jobs/view/python-devel...
# 17  https://in.linkedin.com/jobs/view/python-devel...
# 18  https://in.linkedin.com/jobs/view/python-devel...
# 19  https://in.linkedin.com/jobs/view/backend-pyth...
# 20  https://in.linkedin.com/jobs/view/python-devel...
# 21  https://in.linkedin.com/jobs/view/python-devel...
# 22  https://in.linkedin.com/jobs/view/python-devel...
# 23  https://in.linkedin.com/jobs/view/python-devel...
# 24  https://in.linkedin.com/jobs/view/python-devel...
# 25  https://in.linkedin.com/jobs/view/python-devel...
# 26  https://in.linkedin.com/jobs/view/python-devel...
# 27  https://in.linkedin.com/jobs/view/python-devel...
# 28  https://in.linkedin.com/jobs/view/python-devel...
# 29  https://in.linkedin.com/jobs/view/python-%2B-r...
# 30  https://in.linkedin.com/jobs/view/python-devel...
# 31  https://in.linkedin.com/jobs/view/python-java-...
# 32  https://in.linkedin.com/jobs/view/python-devel...
# 33  https://in.linkedin.com/jobs/view/python-djang...
# 34  https://in.linkedin.com/jobs/view/python-devel...
# 35  https://in.linkedin.com/jobs/view/innovatily-p...
# 36  https://in.linkedin.com/jobs/view/python-devel...
# 37  https://in.linkedin.com/jobs/view/python-autom...
# 38  https://in.linkedin.com/jobs/view/python-devel...
# 39  https://in.linkedin.com/jobs/view/python-devel...
# 40  https://in.linkedin.com/jobs/view/python-devel...
# 41  https://in.linkedin.com/jobs/view/python-devel...
# 42  https://in.linkedin.com/jobs/view/python-devel...
# 43  https://in.linkedin.com/jobs/view/python-devel...

# %%
df=df.iloc[:10,:]
df
# Out:
#                Company Name                             Job Title  \
# 0            Crum & Forster                          Data Analyst
# 1                    Amazon                          Data Analyst
# 2         Helmerich & Payne                          Data Analyst
# 3               Volvo Group                          Data Analyst
# 4               Rebel Foods                        Data Analyst-I
# 5                     Masai  Data Analytics (0-1 Year Experience)
# 6  Greystar (International)                          Data Analyst
# 7    Decathlon Sports India                   Senior Data Analyst
# 8               Kraft Heinz                          Data Analyst
# 9               Kraft Heinz                          Data Analyst
#
#                             Location  \
# 0        Bengaluru, Karnataka, India
# 1        Bengaluru, Karnataka, India
# 2              North Goa, Goa, India
# 3          Hoskote, Karnataka, India
# 4         Mumbai, Maharashtra, India
# 5        Bengaluru, Karnataka, India
# 6             Mohali district, India
# 7  Bengaluru North, Karnataka, India
# 8          Ahmedabad, Gujarat, India
# 9          Ahmedabad, Gujarat, India
#
#                                          Website URL
# 0  https://in.linkedin.com/jobs/view/data-analyst...
# 1  https://in.linkedin.com/jobs/view/data-analyst...
# 2  https://in.linkedin.com/jobs/view/data-analyst...
# 3  https://in.linkedin.com/jobs/view/data-analyst...
# 4  https://in.linkedin.com/jobs/view/data-analyst...
# 5  https://in.linkedin.com/jobs/view/data-analyti...
# 6  https://in.linkedin.com/jobs/view/data-analyst...
# 7  https://in.linkedin.com/jobs/view/senior-data-...
# 8  https://in.linkedin.com/jobs/view/data-analyst...
# 9  https://in.linkedin.com/jobs/view/data-analyst...

# %%
def description(link):

    driver.get(link)
    time.sleep(3)

    driver.find_element(by=By.CSS_SELECTOR, value='button[data-tracking-control-name="public_jobs_show-more-html-btn"]').click()
    time.sleep(2)

    description = driver.find_elements(by=By.CSS_SELECTOR, value='div[class="show-more-less-html__markup relative overflow-hidden"]')
    driver.implicitly_wait(4)
    
    for j in description:
        return j.text

# %%
website_url = df['Website URL'].tolist()

job_description = []

for i in website_url:
    data = description(i)
    if data is not None and len(data.strip()) > 0:
        job_description.append(data)
    else:
        job_description.append('Description Not Available')

# %%
df['Job Description'] = pd.DataFrame(job_description, columns=['Description'])
df
# Out:
#                Company Name                             Job Title  \
# 0            Crum & Forster                          Data Analyst
# 1                    Amazon                          Data Analyst
# 2         Helmerich & Payne                          Data Analyst
# 3               Volvo Group                          Data Analyst
# 4               Rebel Foods                        Data Analyst-I
# 5                     Masai  Data Analytics (0-1 Year Experience)
# 6  Greystar (International)                          Data Analyst
# 7    Decathlon Sports India                   Senior Data Analyst
# 8               Kraft Heinz                          Data Analyst
# 9               Kraft Heinz                          Data Analyst
#
#                             Location  \
# 0        Bengaluru, Karnataka, India
# 1        Bengaluru, Karnataka, India
# 2              North Goa, Goa, India
# 3          Hoskote, Karnataka, India
# 4         Mumbai, Maharashtra, India
# 5        Bengaluru, Karnataka, India
# 6             Mohali district, India
# 7  Bengaluru North, Karnataka, India
# 8          Ahmedabad, Gujarat, India
# 9          Ahmedabad, Gujarat, India
#
#                                          Website URL  \
# 0  https://in.linkedin.com/jobs/view/data-analyst...
# 1  https://in.linkedin.com/jobs/view/data-analyst...
# 2  https://in.linkedin.com/jobs/view/data-analyst...
# 3  https://in.linkedin.com/jobs/view/data-analyst...
# 4  https://in.linkedin.com/jobs/view/data-analyst...
# 5  https://in.linkedin.com/jobs/view/data-analyti...
# 6  https://in.linkedin.com/jobs/view/data-analyst...
# 7  https://in.linkedin.com/jobs/view/senior-data-...
# 8  https://in.linkedin.com/jobs/view/data-analyst...
# 9  https://in.linkedin.com/jobs/view/data-analyst...
#
#                                      Job Description
# 0  Crum & Forster Company Overview\n\nCrum & Fors...
# 1  Description\n\nAt Amazon, we're working to be ...
# 2  About Us\nH&P(Helmerich & Payne) acquired MagV...
# 3  Transport is at the core of modern society. Im...
# 4  About Us:\nWe are surrounded by the world's le...
# 5  We are looking for a Data Analyst to join our ...
# 6  We are looking for candidate with strong knowl...
# 7  YOUR MISSION AT DECATHLON:\n\nDECATHLON is acc...
# 8  Data Analyst-\n\nKey Responsibilities\n• Desig...
# 9  Data Analyst-\n\nKey Responsibilities\n• Desig...

# %%
l = len(df['Company Name'])
for i in range(0,l):
    print(f"Company Name : {df.iloc[i,0]}")
    print(f"Job Title    : {df.iloc[i,1]}")
    print(f"Location     : {df.iloc[i,2]}")
    print(f"Website URL  : {df.iloc[i,3]}")
    print(f"Description  : {df.iloc[i,4]}")
# Out:
# Company Name : Crum & Forster
# Job Title    : Data Analyst
# Location     : Bengaluru, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-at-crum-forster-3868419975?position=1&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=0Hfwj1cKYPJcZP9hPoiekA%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Crum & Forster Company Overview
#
# Crum & Forster (C&F), with a proud history dating to 1822, provides specialty and standard commercial lines insurance products through our admitted and surplus lines insurance companies.
# Approaching $4 billion in written premium as of 2021, C&F enjoys an “A” (Excellent) financial strength rating by A.M. Best.
#
# C&F is part of Fairfax Financial Holdings, a global organization with $23.8 billion in revenue as of 2021.
#
# Crum & Forster Services India (CFSI) is an India subsidiary of Crum & Forster Inc. The objective is to provide digital and IT services to C&F business units by creating autonomous squads focused on a specific product or a business team.
#
# Position:
#
# The Digital Data Services Cloud Developer will work with a group of highly motivated and experienced technologists who have spent the past several years working hard to implement innovative tools to the C&F Surplus & Specialty Division for quick and scalable business solutions.
#
# Key Responsibilities:
#
# Develop, maintain, and manage advanced reporting, analytics, dashboards and other BI solutions.
# Performing and documenting data analysis, data validation, and data mapping/design.
# Working with the other Digital teams to help provide reporting and analytical solutions to new systems and portals as they are developed.
# Working with the full suite of AWS Services (CLI, EC2, S3, Lambda, DMS, Glue, etc…)
# Working with databases such as Microsoft SQL Server, Oracle, PostgreSQL, MySQL, DynamoDB, by developing queries, views, tables, etc, to facilitate data solutions.
# Working with Microsoft SQL Server tools (SSMS, SSIS, SSRS)
# Working with databases and data pipelines in Snowflake
# Data Lake development for reporting, analytics and machine learning purposes
# Data ingestion using Fivetran, AirByte or other near-real-time data intake tools
# Working with the various business units to analyze need, recommend solutions, and work with the team to prioritize, plan, and execute on deliverables
# Using Confluence and JIRA to manage tasks, projects, and documentation
# Working with version control software such as Git and Bitbucket
# Communicate with other Digital teams, as well as the Business Units, to clearly define project goals, discuss timelines, and provide input on solutions
#
# What are we looking for?
#
# Required Knowledge and Skills:
#
# Must have skills
#
# A passion for learning
# Knowledge of efficiency techniques when building queries and developing reports/dashboards
# Experience in developing, maintaining, and managing SSRS Reports
# Experience in developing, maintaining and managing Tableau dashboards and working knowledge of Tableau administration/architecture
# Proficiency in use of query and reporting analysis tools
# Strong SQL background
# Experience with Production Support and Troubleshooting
# Great communication, note taking, and organizational skills
# Experience with Amazon Web Services (Certification a plus, not required)
# Working knowledge of core AWS services and public cloud implementation
# Experience with the following a plus: Snowflake, Fivetran, QuickSight, AirByte
# In-depth knowledge of one or more of these programming languages: Python, JavaScript, Java and similar
# Experience working with APIs
# Insurance industry knowledge a plus
# Fair and friendly approach
# Good understanding of the SDLC process (how software is built)
# An ability to leverage web searches and online training to obtain new skills quickly
# An ability to present to all levels of audience
# A passion for a dynamic, fast changing environment
# An enthusiastic and positive attitude
# An innovative, entrepreneurial spirit
# Experience working with external vendors
# Ability to take ownership and see tasks through to completion
# Will abide by departmental policies and procedures, including authority levels, to comply with C&F’s management controls.
# Degree or certification in Computer Science, Statistics, Mathematics, Business, or equivalent
#
# At C&F you will BELONG
#
# If you require special accommodations, please let us know. We value inclusivity and diversity. We are committed to equal employment opportunity and welcome everyone regardless of race, color, ancestry, religion, sex, national origin, sexual orientation, age, citizenship, marital status, disability, gender identity, or Veteran status . If you require special accommodations, please let us know
# Company Name : Amazon
# Job Title    : Data Analyst
# Location     : Bengaluru, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-at-amazon-3901710478?position=2&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=rVdJ5%2BnY8Hh7Lgu6R2nXVA%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Description
#
# At Amazon, we're working to be the most customer-centric company on earth. To get there, we need exceptionally talented, bright, and driven people. We are looking for a talented, driven and experienced Business Analyst. It is a pivotal role that will contribute to the evolution and success of one of the key priorities of the organization by insights mining and data modelling to make high impact decisions that reduce time to identify abuse.
#
# Key Deliverables Of The Role
#
# Own the weekly/monthly dashboards for key metric tracking and associated deep dives
# Automate data templates and reports
# Engage with cross-team stakeholders to help run deep dives, test hypothesis and impact of ML/product changes made, on key metrics
#
# Key job responsibilities
#
# SQL skills
# Microsoft Excel
# Passion for converting data to insights, building frameworks for decision making, high attention to details and data fidelity
# Ability to prioritize and focus on high impact areas
# Teamwork and problem solving skills
#
# We are open to hiring candidates to work out of one of the following locations:
#
# Bangalore, KA, IND
#
# Basic Qualifications
#
# 1+ years of business analysis (dealing with large complex data) experience
# Knowledge of SQL and Excel at a moderate or advanced level
# Bachelor's degree
# Experience working directly with business teams to utilize metrics and analysis to determine improvement opportunities
#
# Preferred Qualifications
#
# Knowledge of SQL/Python/R, scripting, MS Excel, table joins, and aggregate analytical functions
#
#
# Company - ASSPL - Karnataka
#
# Job ID: A2613934
# Company Name : Helmerich & Payne
# Job Title    : Data Analyst
# Location     : North Goa, Goa, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-at-helmerich-payne-3897710307?position=3&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=YrHQImi5h19KhmkIV%2FzEMQ%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : About Us
# H&P(Helmerich & Payne) acquired MagVar and Motive Drilling which have become the centerpiece of H&P Technologies. We drive the development of advanced technologies and directional drilling automation solutions to help customers achieve greater reliability and well performance. We are focused on leading-edge technology pushing the limits of the oil & gas industry. Our Value-Driven Automation platform offer customers an unrivalled opportunity to drill longer laterals, increase well placement accuracy and maximize yield. We have software teams in Denver, Dallas and India. Helmerich & Payne, Inc. has been the industry's most trusted partner in U.S. land, international and offshore drilling productivity and reliability since 1920. Our company currently owns and operates land rigs across North America, South America, the Middle East and Africa, with offshore rigs in the Gulf of Mexico.
#
# Role: HR Data Analyst
# Job Location: Goa, India
# Work model: work from Office
# Company: www.helmerichpayne.com
#
# Requirement:
# Bachelor's degree, Business Analytics/Statistics/Data Science, or a related field.
# Proven experience as an HR Data Analyst or in a similar analytical role.
# Strong proficiency in data analysis and visualization tools, such as Excel, SQL, Power BI, or other statistical software.
# Solid understanding of HR processes, policies, and best practices.
# Familiarity with Workday and its data structure.
# Proficient in data manipulation, cleaning, and transformation techniques.
# Strong analytical and problem-solving skills with a keen attention to detail.
# Excellent communication skills, both verbal and written, with the ability to present complex data in a clear and concise manner.
# Ability to work independently and collaborate effectively in a team-oriented environment.
# Knowledge of data governance principles and data protection regulations is a plus.
#
# Responsibilities:
# 1. Data Collection and Analysis:
# Gather, organize, and analyze HR data from various sources, including HRIS, employee surveys, performance evaluations, and other relevant systems.
# Conduct data cleaning, validation, and manipulation to ensure accuracy and consistency.
# Develop and maintain data dashboards, reports, and visualizations to effectively communicate HR metrics and trends.
#
# 2. HR Metrics and Reporting:
# Identify and track key HR metrics, such as employee turnover, recruitment effectiveness, diversity and inclusion, and employee engagement.
# Prepare regular reports and presentations to HR management and other stakeholders, highlighting trends, patterns, and actionable insights derived from HR data analysis.
# Collaborate with HR business partners to identify data needs and design customized reports to support their decision-making processes.
#
# 3. Data Interpretation and Insight Generation:
# Conduct advanced statistical analysis to identify patterns, correlations, and trends in HR data.
# Provide meaningful insights and recommendations based on data analysis to improve HR processes, policies, and strategies.
# Assist in forecasting future HR trends and their potential impact on the organization.
#
# 4. Data Governance and Compliance:
# Ensure data integrity, confidentiality, and compliance with data protection regulations.
# Develop and implement data governance procedures and best practices for HR data management.
# Stay up to date with industry trends and best practices related to HR analytics and data management.
#
# 5. Cross-functional Collaboration:
# Collaborate with other teams, such as Finance, Operations, and IT, to integrate HR data with other organizational data for comprehensive analysis.
# Work closely with HR stakeholders to understand their analytical requirements and provide actionable insights to support their decision-making processes.
#
# Please let me know if you would be interested and available & if interested, please share your updated resume along with your contact details.
#
# Looking forward to your reply.
#
# Thanks and Regards,
# Hortencia Fernandes
# Company Name : Volvo Group
# Job Title    : Data Analyst
# Location     : Hoskote, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-at-volvo-group-3900523046?position=4&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=RufR9pgcizL6lUytMS6vdA%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Transport is at the core of modern society. Imagine using your expertise to shape sustainable transport solutions for the future? If you seek to make a difference on a global scale, working with next-gen technologies and the sharpest collaborative teams, then we could be a perfect match.
#
# What You Will Do
#
# We are now recruiting a Data Analyst
#
# Our organization is the perfect platform for people who want to make a difference in Supply Chain. You need to be passionate about making things better for our Supply Chain, organization, and our society.
#
# YOUR NEW ROLE
#
# In this position, you will be a member of the TD&O, which includes transport network optimization (TNO), TMS key users and supplier management functions with the responsibility for design, implement, optimize, and secure quality of the transport network for transport material, transport product and manage packaging.
#
# Your most important assignment in this role is to master data update, data update and data analytics. You are also responsible for preparing Volvo Packaging orders, PO, SO and invoice generation. You will be proactively working to improve supplier performance on packaging order. You also need to bring value to operation thru data analytics, visualization, and automation.
#
# You will work in a global supply chain context that provides an interesting diversity both in people and responsibility areas. You will work together with colleagues within TD&O TO INTER but to a great extent also with colleagues in other parts of Production Logistics, in other regions and in development functions. In your role you perform and deliver activities to EMEA region Manage Packaging Operations. Your main interface will be towards Transport Operations, Manage Packaging, Material suppliers and Volvo plants.
#
# THIS IS US, YOUR NEW COLLEAGUES
#
# The Transport Design and Optimization (TD&O) is part of the Transport Operations International (TO INTER) team. TO INTER is together responsible for driving Production Logistics operations with competitive flexibility, delivery precision, sustainability, and cost. We are responsible for transporting material from supplier to plant, managing and distributing packaging material and delivering Volvo products to the final market. Delivery precision is necessary for us to support Volvo operation and we deliver that with high-cost focus and environmental awareness.
#
# Who are you?
#
# We are looking for you who can bring in new perspectives to the continued development of the Volvo Packaing Operations. You are an experienced, energized person who sees the benefit of building strong relationships and cross functional collaboration. You are a person that enjoys working with a broad spectrum of stakeholders and loves the challenges our high pace and our operational environment brings. You are ambitious and innovative, you will have Analytical, Digitalization and Sustainability skills. You know about analytical tools i.e Power BI, Power Apps, Qlik sense, Advanced Excel etc.
#
#
#
# We believe that it is an advantage if you have experience from production or logistics and supply chain environment.
#
# What’s in it for you?
#
# We cannot promise you an effortless job, but we can promise you some skilled colleagues and some truly exciting challenges to work with. As you will be part of an organization of skilled people your passion for innovative technology, innovation and fresh solutions shines through. We believe it is only together that we can create great business, and it is only together that we will make this world a better place. If you have a great capability to involve, motivate and engage others then we are certain that you would be a great asset to our team.
#
# Responsiblities
#
# Planning and Distribution of Packaging Orders in SAP and EBD
# Create new packaging orders based on global planning and forecasting
# Purchase order and Sales order creation
# Prepare workflow Invoices
# Validate extra cost charged
# Validate and secure missing goods receipt
# Proactive work with material suppliers to improve erratic order behavior
# Proactively work to avoid incorrect and missing orders
# Analyse orders and distribution data to improve supplier order accuracy
# Prepare analytical tools, dashboard to bring operational excellence and efficiency
# Solve business problems thru data analytics
#
# Competence s
#
# Driver/Project leader
# Structured mindset and analytical skills
# Team player with good interpersonal, presentation and networking skills to build strong internal and external relationships with stakeholders
# Problem solving and self-going attitude
# Active contributor to the lean methodology
# Motivated and determined to reach agreed objectives, (K)PI’s
# Customer focused attitude
# Supply Chain knowledge with holistic view
# Ability to independently generate ideas and demonstrate creativity
#
# We value your data privacy and therefore do not accept applications via mail.
#
# Who We Are And What We Believe In
#
# Our focus on Inclusion, Diversity, and Equity allows each of us the opportunity to bring our full authentic self to work and thrive by providing a safe and supportive environment, free of harassment and discrimination. We are committed to removing the barriers to entry, which is why we ask that even if you feel you may not meet every qualification on the job description, please apply and let us decide.
#
# Applying to this job offers you the opportunity to join Volvo Group. Every day, across the globe, our trucks, buses, engines, construction equipment, financial services, and solutions make modern life possible. We are almost 100,000 people empowered to shape the future landscape of efficient, safe and sustainable transport solutions. Fulfilling our mission creates countless career opportunities for talents with sharp minds and passion across the group’s leading brands and entities.
#
# Group Trucks Operations encompasses all production of the Group’s manufacturing of Volvo, Renault and Mack trucks, as well as engines and transmissions. We also orchestrate the spare parts distribution for Volvo Group’s customers globally and design, operate and optimize logistics and supply chains for all brands. We count 30,000 employees at 30 plants and 50 distribution centers across the globe. Our global footprint offers an opportunity for an international career in a state-of-the-art industrial environment, where continuous improvement is the foundation. As our planet is facing great challenges, we - one of the largest industrial organizations in the world - stand at the forefront of innovation. We are ready to rise to the challenge. Would you like to join us?
# Company Name : Rebel Foods
# Job Title    : Data Analyst-I
# Location     : Mumbai, Maharashtra, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-i-at-rebel-foods-3900892007?position=5&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=PjIa8imsz6KKrslotmyk1A%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : About Us:
# We are surrounded by the world's leading consumer companies led by technology - Amazon for retail, Airbnb for hospitality, Uber for mobility, Netflix and Spotify for entertainment, etc. Food & Beverage is the only consumer sector where large players are still traditional restaurant companies. At Rebel Foods, we are challenging this status quo as we are building the world's most valuable restaurant company on the internet, superfast.
# The opportunity for us is immense due to the exponential growth in the food delivery business worldwide which has helped us build 'The World's Largest Internet Restaurant Company' in the last few years. Rebel Foods' current presence in 3 countries (India, MENA, and UK) with 15 + brands and 3500+ internet restaurants has been built on a simple system - The Rebel Operating Model.
# While for us it is still Day 1, we know we are in the middle of a revolution towards creating never-seen-before customer-first experiences. We bring you a once-in-a-lifetime opportunity to disrupt the 500-year-old industry with technology at its core.
#
# The Rebel Culture
# Finally, but most importantly, Rebel is not a usual workplace. The following slides will give you a sense of our culture, how Rebel conducts itself and who will fit into the company. Please go through it before you make up your mind. It’s not everyone’s cup of tea.
#
# https://www.slideshare.net/JaydeepBarman/culture-rebel
#
# The Role:
# Understanding Business and Data Requirements from stakeholders
# Creating Business Reports
# Report Automation
# Creating Dashboards/Visualizations for Business KPIs
# Data Mining for Business Insights
# Initiatives based on business needs and requirements
# Evaluating business processes, uncovering areas of improvement, optimizing strategies and implementing solutions
# Problem-solving skills
#
# Requirements:
# Acquire, aggregate, restructure, and analyze large datasets.
# Ability to work with various SQL and No-SQL data sources, S3, APIs etc.
# Data manipulation experience with Python/Pandas
# Exhibit strong analytic, technical, trouble-shooting, and problem-solving skills
# Ability to work in a team-oriented, fast-paced environment managing multiple
# priorities
# Project management and organizational skills
# Good to know: predictive modelling
# Able to work on AWS cloud (S3, batch jobs, cloud watch)
# Used Jenkins and Docker for CI CD
#
# Languages - SQL, Python (Pandas)
# BI Tools - Quicksight/Tableau
#
# Unique Opportunity
# Get a chance to work on Deep Analytics systems built on large amounts of multi-source data around orders, customers, sales, kitchen systems, etc.
# Empower business decision-making of every team at Rebel across supply, demand, offer optimization, personalization and customer experience
# Get a chance to improve Data Science & Machine Learning performance by creating the right visibility around model performance & feature enhancements
# Company Name : Masai
# Job Title    : Data Analytics (0-1 Year Experience)
# Location     : Bengaluru, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analytics-0-1-year-experience-at-masai-3905607817?position=6&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=vZn3UtqZTotgZpLNZslgKQ%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : We are looking for a Data Analyst to join our data analytics team. The ideal candidate should have a passion for data and analytics, along with strong analytical skills. As a Data Analyst, you will be responsible for collecting, analyzing, and interpreting large datasets to provide valuable insights to support business decisions.
#
# Responsibilities
#
# Collecting and interpreting data from various sources
# Cleaning, transforming, and organizing data for analysis
# Performing statistical analysis and data modeling
# Creating data visualizations and reports to communicate findings
# Identifying trends, patterns, and correlations in data
# Collaborating with cross-functional teams to understand business requirements
# Presenting findings and recommendations to stakeholders
#
# Requirements
#
# Bachelor’s degree in Computer Science, Mathematics, Statistics, Economics, Course or skill in related field
# Strong analytical and problem-solving skills
# Proficiency in SQL and data manipulation languages (e.g., Python, R)
# Experience with data visualization tools (e.g., Tableau, Power BI)
# Knowledge of statistical techniques and methods
# Excellent communication and presentation skills
# Ability to work independently and collaboratively in a team environment
#
# Skills: statistical techniques,data visualization,sql,statistical analysis,interpreting,power bi,business requirements,team collaboration,skills,data manipulation,data collection,r,data modeling,computer science,python,data,data analysis,data analytics,tableau,reporting,analytics,communication,analytical skills,presentation,data interpretation
# Company Name : Greystar (International)
# Job Title    : Data Analyst
# Location     : Mohali district, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-at-greystar-international-3890937042?position=7&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=gVmZJSuJpmAtDXnQfRCBqg%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : We are looking for candidate with strong knowledge and experience with Power BI dashboard design and creation. The candidate should be able to clearly communicate with end-users on dashboard design, issue resolution and implementing design enhancements. Perform data modeling and create mapping tables and parameters in Power BI desktop and service. Create DAX calculation and formulas, and Power Query transformations. Prepare dataflows as imports and/or direct connections. Assist with configuring security hierarchies. Create alarms, alerting and notifications using Azure Power BI automation. Manage gateways, data extracts and data source refreshes. Knowledge of Snowflake database.
#
# Primarily focused on
#
# Process of consolidating separate data and reporting suites
# Ensure business users are enabled with carefully curated data visualizations with accurate, reliable and consistent data to monitor contract performance and assist in decision making
# Determining reporting needs, developing, and building reports, training users and establishing reporting cadences and processes
# Fulfilling the below roles and responsibilities
#
# Evaluate business needs and objectives.
# Conduct complex data analysis and report on results.
# Analyze and organize raw data.
# Leverage data sets and data flows
# Shape and combine multiple data sources.
# Prepare data models.
# Build and demonstrate prototypes, visualizations, and reports.
# Explore ways to improve visualizations and data models.
# Collaborate with data and analytics team members.
# Experience with Data Warehousing, Data Modeling, Power BI, Power Query, DAX and related technologies
# Evaluate report performance metrics and implement improvements.
# Bringing in the below experience
#
# 5+ years of experience as an IT business analyst working closely with the business and functionally designing reports
# Expert knowledge of DAX (5+ years)
# Expert knowledge/experience with setting up security, managing workspaces, data flows in Power BI (both desktop and Power BI service) (3+ years)
# Experience in Power Query and M language (3+ years)
# Expert knowledge of SQL
# Good understanding of Data Architecture (2+ years)
# Experience in creating customized Power BI Dashboards/reports
# Technical experience in Power BI composite, multi-dimensional models, and row-level security is a plus
# Strong analytical skills applied to understanding business functionality and the KPI metrics they need to report to effectively manage their business and translate them into reporting and dashboard requirements.
# Ability to adapt quickly to new technologies and changing business requirements.
# Technically sound in
#
# Knowledge working Power BI Desktop, Power BI Service and Workspaces, Power Query, and DAX
# Knowledge working with SQL Server TSQL stored procedures
# Proficiency in software such as, word processing, spreadsheet, and database management programs to develop and/or complete required reports
# What We Offer
#
# We include a range of benefits for our corporate team members, including competitive pension and healthcare amongst others as standard. Please reach out if you are keen to know more.
# About Greystar
#
# Greystar is a leading, fully integrated real estate company offering expertise in investment management, development, and management of rental housing properties globally. The company's business model is unique in its ability to own, operate, and develop multifamily, student, and senior housing across the globe. Building a global platform with a local presence, Greystar continues to expand its geographic reach around the world, bringing a globally interconnected professional rental housing platform and industry funded with institutional capital to countries where the sector does not yet exist. Greystar’s pan – European platform was established in 2013 and has scaled rapidly, now with investment, operational and development presence in the UK, Ireland, France, the Netherlands, Germany, Austria, and Spain.
#
# One of Greystar’s core values is Equality, and as such, we continue to pride ourselves on being an equal opportunities employer, accounting for all protected and identifiable characteristics. We truly value diversity of thought, background and of experience. Please reach out to the Talent Acquisition team to explore opportunities at Greystar in more detail or visit our careers site at https://jobs.greystar.com/.
# Company Name : Decathlon Sports India
# Job Title    : Senior Data Analyst
# Location     : Bengaluru North, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/senior-data-analyst-at-decathlon-sports-india-3903721378?position=8&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=OiHcxF52xwY7DfX9tSIgeg%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : YOUR MISSION AT DECATHLON:
#
# DECATHLON is accelerating its digital transformation with an ambitious mission of becoming THE digital sports platform that will allow customers to discover sports through many local experiences across the world.
# Our goal is to create an open ecosystem in order to connect numerous actors and third-party services, in a safe and efficient way.
# Our Technology & Digital teams based in Bengaluru are united to build and grow Decathlon India digital products & solutions with the aim of always offering the best value to 1.3 billion users in India.
#
# About the job
# Love Sport? Customer Focused? Data Analyst?
# If Yes, This is the perfect role for you
# As a member of the Data and Analytics Team, you will enable insights needed for the numeric transformation of Decathlon.
#
# We are looking for an exceptional Senior Insights Analyst, who understands that Analytics is NOT dashboarding. If you're someone who believes that data is more than just numbers and that true insights come from rigorous analysis, this role is for you.
# What we are looking for:
# -> Logical Thinker: Your ability to dissect complex problems and create structured solutions is unparalleled.
# -> Analysis-First Mindset: Before action comes analysis. We need someone who dives deep into the data, challenges assumptions, and emerges with insights that drive decisions.
# -> Problem Solver: Faced with a challenge? You see it as an opportunity to grow, learn, and innovate. You're not deterred by the unknown.
# -> Tech-Savvy: Proficient in Python and SQL, you leverage technology to amplify your analytical capabilities.
# -> Industry Experience: Familiarity with retail trends, challenges, and the unique nature of retail data is a plus!
# Responsibilities
# Act as a Single Point of Contact for all data repositories and develop metrics to analyze pertinent information and share insights through various reports, dashboards on a sustainable basis.
# Deep-dive into data trends to identify root causes and improvement opportunities.
# Identify trends, patterns and concerns emerging from data and highlight the same to management & internal stakeholders, with recommendations in a clear, concise manner to enable smooth and quick decision making.
# Build data models in order to create reporting infrastructure/dashboards for business process management and data mining
# Execute quantitative analysis that translates data into actionable insights
# Enable drive data driven decision making and generate insights for the business
# Skills
# Excellent data analysis skills
# AWS Redshift
# SQL and Python
# Databricks
# Visualization tool - Tableau
# Desired Qualifications
# Atleast 5 years of experience in data analytics
# Experience in e-Commerce, Retail or CPG industry is a strong plus.
# Strong Knowledge in Data
# Leadership abilities and strong stakeholder management skills
# Very good oral and written communication skills
# Likes to practice sports (need not be a professional, but love to practice leisurely)
# Currently based out of Bengaluru or willing to relocate
# What we offer:
# Culture of work & sports together
# Freedom of choice of work station (Mac, Windows)
# Local project team and close proximity with the global network (international collaboration)
# Better opportunity to increase technological skills & professional capability(diversity of projects, languages and technologies)
# Internal and external training
# Shareholding
# Monthly company performance bonus (Subject to country performance)
# Company Name : Kraft Heinz
# Job Title    : Data Analyst
# Location     : Ahmedabad, Gujarat, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-at-kraft-heinz-3901329745?position=9&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=86wJrsGEcfZIV73L8WiWVQ%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Data Analyst-
#
# Key Responsibilities
# • Design and deliver the appropriate analytical approach to address key issues within the organization, by understanding the business problem (through discovery sessions with business SMEs) and translating into analytical requirements.
# • Gather detailed user requirements and collaborate with a cross-functional team to deliver high quality results (such as data engineers, business users).
# • Manage the delivery of analytical tools from discovery, build and ongoing iterative development. Manage the communication with the business SMEs throughout.
# • Build, maintain and enhance analytical solutions including performant Tableau dashboards and interactive reports across multiple functions and disciplines within Kraft Heinz globally.
# • Manage and coach junior analysts on the analytical development of solutions.
# • Build workflows or scripts that facilitate data preparation, data cleansing and rapid prototyping.
# • Automate repetitive manual tasks and support the development process to improve speed to insight.
# • Build strong relationships with business stakeholders and work hand in hand to deliver analytical solutions.
# • Gather user feedback and bugs and manage in a backlog, ordering per business priority. Work in Agile Sprints to execute the backlog.
# • Execute enhancement requests to further improve products post go-live to drive adoption and support change management. • Ensure thorough testing of products in lower environments before go-live, after which the candidate must manage and fix any bugs to ensure consistency in the tools. • Raise issues and risks in a timely manner to project manager to ensure appropriate actions can be taken to mitigate. • Ensure effective and timely delivery of project work.
#
# Qualifications & Experience
# • Bachelor or Master degree. Preference for business, computer science, statistics, data science
# • 4-8 years of relevant experience, preferably as an analyst or Tableau developer. FMCG experience highly desired by not essentials.
# • Strong analytical skills • Language Knowledge: English • Solid experience building Interactive Visualizations such as Tableau. • Hands on experience in Programming Languages such as Python, R or any other programming languages • Hands on experience building extract, transform, load (ETL) data pipelines and SQL skills
# • Excellent communication skills with ability to understand and translate business problems and logic into analytical requirements • Ability to simplify complex logic and present clearly to business stakeholders • Understanding of numbers, ability to sense check independently • Understanding of and working against the importance of managing deadlines • Demonstrated experience collaborating with multiple stakeholders across functions and time zones • Experience in a dynamic and fast-paced environment • Experience and understanding of statistical analysis is a plus • Experience working in an Agile DevOps team is highly desirable
#
# Professional Attributes
# • Communication Skills
# o At Kraft Heinz you’ll easily be exposed to senior management, no matter your level. Therefore, it’s important you have excellent communication skills, to deal with all kinds of different stakeholders. • Analytical o We’re a very data driven company. You know how to translate complex data into a simple solution with your analytical mindset.
# • Curiosity, positivity & enthusiasm
# o You’re curious, positive and enthusiastic. People know you as the driver of the team.
# • Project management skills
# o Time management has no secrets for you. You’re organized, structured and always have an overview of all the deliverables. You know how to bring multiple projects to a successful ending within the given timeframe.
# • Team player
# o Achieving results is nice, but achieving results with the team is simply the best. You’re a team player, which means you’re sometimes a leader, sometimes a follower but always working towards the same common goal together with your teammates.
# What we offer you
# • An ambitious employer; we only want to the best for you;
# • A fast career track like only few other companies can match;
# • A competitive salary
# • Always room for new ideas; if you have an excellent idea, please let us know and we can set it in action!
# Company Name : Kraft Heinz
# Job Title    : Data Analyst
# Location     : Ahmedabad, Gujarat, India
# Website URL  : https://in.linkedin.com/jobs/view/data-analyst-at-kraft-heinz-3901325900?position=10&pageNum=0&refId=MQKTJUVz3xu3f78SPw1MFQ%3D%3D&trackingId=4epKCQ11r1MWxokl5hs0uQ%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Data Analyst-
#
# Key Responsibilities
# • Design and deliver the appropriate analytical approach to address key issues within the organization, by understanding the business problem (through discovery sessions with business SMEs) and translating into analytical requirements.
# • Gather detailed user requirements and collaborate with a cross-functional team to deliver high quality results (such as data engineers, business users).
# • Manage the delivery of analytical tools from discovery, build and ongoing iterative development. Manage the communication with the business SMEs throughout.
# • Build, maintain and enhance analytical solutions including performant Tableau dashboards and interactive reports across multiple functions and disciplines within Kraft Heinz globally.
# • Manage and coach junior analysts on the analytical development of solutions.
# • Build workflows or scripts that facilitate data preparation, data cleansing and rapid prototyping.
# • Automate repetitive manual tasks and support the development process to improve speed to insight.
# • Build strong relationships with business stakeholders and work hand in hand to deliver analytical solutions.
# • Gather user feedback and bugs and manage in a backlog, ordering per business priority. Work in Agile Sprints to execute the backlog.
# • Execute enhancement requests to further improve products post go-live to drive adoption and support change management. • Ensure thorough testing of products in lower environments before go-live, after which the candidate must manage and fix any bugs to ensure consistency in the tools. • Raise issues and risks in a timely manner to project manager to ensure appropriate actions can be taken to mitigate. • Ensure effective and timely delivery of project work.
#
# Qualifications & Experience
# • Bachelor or Master degree. Preference for business, computer science, statistics, data science
# • 4-8 years of relevant experience, preferably as an analyst or Tableau developer. FMCG experience highly desired by not essentials.
# • Strong analytical skills • Language Knowledge: English • Solid experience building Interactive Visualizations such as Tableau. • Hands on experience in Programming Languages such as Python, R or any other programming languages • Hands on experience building extract, transform, load (ETL) data pipelines and SQL skills
# • Excellent communication skills with ability to understand and translate business problems and logic into analytical requirements • Ability to simplify complex logic and present clearly to business stakeholders • Understanding of numbers, ability to sense check independently • Understanding of and working against the importance of managing deadlines • Demonstrated experience collaborating with multiple stakeholders across functions and time zones • Experience in a dynamic and fast-paced environment • Experience and understanding of statistical analysis is a plus • Experience working in an Agile DevOps team is highly desirable
#
# Professional Attributes
# • Communication Skills
# o At Kraft Heinz you’ll easily be exposed to senior management, no matter your level. Therefore, it’s important you have excellent communication skills, to deal with all kinds of different stakeholders. • Analytical o We’re a very data driven company. You know how to translate complex data into a simple solution with your analytical mindset.
# • Curiosity, positivity & enthusiasm
# o You’re curious, positive and enthusiastic. People know you as the driver of the team.
# • Project management skills
# o Time management has no secrets for you. You’re organized, structured and always have an overview of all the deliverables. You know how to bring multiple projects to a successful ending within the given timeframe.
# • Team player
# o Achieving results is nice, but achieving results with the team is simply the best. You’re a team player, which means you’re sometimes a leader, sometimes a follower but always working towards the same common goal together with your teammates.
# What we offer you
# • An ambitious employer; we only want to the best for you;
# • A fast career track like only few other companies can match;
# • A competitive salary
# • Always room for new ideas; if you have an excellent idea, please let us know and we can set it in action!
